# %% [markdown]
# # Week 1 Seminar
#
# A/B experiment analysis

# %%
from collections import namedtuple

import pandas as pd
import numpy as np
import scipy.stats as ss

import matplotlib.pyplot as plt

pd.set_option("display.precision", 3)

# %matplotlib inline

# %%
experiment = "MY_RECOMMENDERS"

# %%
data = pd.read_json("~/Desktop/log/data.json", lines=True)
data["treatment"] = data["experiments"].map(lambda experiments: experiments[experiment])

# %%
data.head()
# Out:
#   message               timestamp  user  track  time    latency  \
# 0    next 2023-04-15 17:23:59.534  7212  42478  1.00  4.667e-03
# 1    next 2023-04-15 17:23:59.536  7212  42478  1.00  7.997e-04
# 2    next 2023-04-15 17:23:59.539  7212   1206  0.59  7.577e-04
# 3    next 2023-04-15 17:23:59.540  7212   1476  0.04  7.341e-04
# 4    next 2023-04-15 17:23:59.542  7212   1553  0.06  7.372e-04
#
#    recommendation                experiments treatment
# 0          1206.0  {'MY_RECOMMENDERS': 'T4'}        T4
# 1          1476.0  {'MY_RECOMMENDERS': 'T4'}        T4
# 2          1553.0  {'MY_RECOMMENDERS': 'T4'}        T4
# 3          1544.0  {'MY_RECOMMENDERS': 'T4'}        T4
# 4           178.0  {'MY_RECOMMENDERS': 'T4'}        T4

# %% [markdown]
# ## Visualize sessions

# %%
Session = namedtuple("Session", ["timestamp", "tracks", "time", "latency"])

def sessionize(user_data):
    sessions = []
    session = None
    for _, row in user_data.sort_values("timestamp").iterrows():
        if session is None:
            session = Session(row["timestamp"], 0, 0, 0)
        
        session = session._replace(
            tracks = session.tracks + 1, 
            time = session.time + row["time"],
            latency = session.latency + row["latency"] * 1000,
        )
        
        if row["message"] == "last":
            sessions.append(session._asdict())
            session = None
    return sessions

# %%
sessions = (
    data
    .groupby(["user", "treatment"])
    .apply(sessionize)
    .explode()
    .apply(pd.Series)
)

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["tracks"], label=treatment)
ax.legend()
pass

# %%
figure, ax = plt.subplots(figsize=(15, 5))
for treatment, treatment_sessions in sessions.groupby("treatment"):
    reindexed_treatment_sessions = treatment_sessions.sort_values("timestamp").reset_index()
    ax.plot(reindexed_treatment_sessions.index, reindexed_treatment_sessions["time"], label=treatment)
ax.legend()
pass

# %% [markdown]
# ## Analyze the experiment

# %%
user_level_data = (
  sessions
    .reset_index()
    .groupby(["user", "treatment"])
    .agg(
        {
            "timestamp": "count",
            "tracks": "sum",
            "time": "sum",
            "latency": "sum"
        }
    )
)

user_level_data["sessions"] = user_level_data["timestamp"]
user_level_data["mean_request_latency"] = user_level_data["latency"] / user_level_data["tracks"]
user_level_data["mean_tracks_per_session"] = user_level_data["tracks"] / user_level_data["sessions"]
user_level_data["mean_time_per_session"] = user_level_data["time"] / user_level_data["sessions"]

metrics = [
    "time", 
    "sessions", 
    "mean_request_latency", 
    "mean_tracks_per_session", 
    "mean_time_per_session"
]

user_level_metrics = user_level_data[metrics].copy().reset_index()

# %%
treatment_level_metrics = (
    user_level_metrics
    .groupby("treatment")[metrics]
    .agg(["count", "mean", "var"])
)

# %%
def dof(n_0, n_1, s2_0, s2_1):
    numerator = (s2_0 / n_0 + s2_1 / n_1) * (s2_0 / n_0 + s2_1 / n_1)
    denominator = s2_0 * s2_0 / n_0 / n_0 / (n_0 - 1) + s2_1 * s2_1 / n_1 / n_1 / (n_1 - 1)
    return numerator / denominator


def ci(n_0, n_1, s2_0, s2_1, alpha=0.05):
    return ss.t.ppf(1 - alpha/2, dof(n_0, n_1, s2_0, s2_1)) * np.sqrt(s2_0 / n_0 + s2_1 / n_1)


effects = []

control = [data for treatment, data in treatment_level_metrics.iterrows() if treatment == "C"][0]

for treatment, row in treatment_level_metrics.iterrows():
    if treatment == "C":
        continue
    
    for metric in metrics:
        control_mean = control[metric]["mean"]
        treatment_mean = row[metric]["mean"]
        
        effect = treatment_mean - control_mean
        conf_int = ci(
            control[metric]["count"],
            row[metric]["count"],
            control[metric]["var"],
            row[metric]["var"],
        )
        effects.append({
            "treatment": treatment,
            "metric": metric,
            "control_mean": control_mean,
            "treatment_mean": treatment_mean,
            "effect": effect / control_mean * 100,
            "lower": (effect - conf_int) / control_mean * 100,
            "upper": (effect + conf_int) / control_mean * 100,
            "significant": (effect + conf_int) * (effect - conf_int) > 0
        })

# %%
def color(value):
    return 'color:red;' if value < 0 else 'color:green;'

def background(value):
    return 'color:white;background-color:green' if value else 'color:white;background-color:red'


(
    pd.DataFrame(effects)[[
        "treatment",
        "metric",
        "effect",
        "upper",
        "lower",
        "control_mean",
        "treatment_mean",
        "significant"
    ]]
    .sort_values(["metric", "treatment"], ascending=False)
    .style
    .applymap(color, subset=["effect", "upper", "lower"])
    .applymap(background, subset=["significant"])
)
# Out:
# <style type="text/css">
# #T_2b606_row0_col2, #T_2b606_row0_col3, #T_2b606_row0_col4, #T_2b606_row1_col2, #T_2b606_row1_col3, #T_2b606_row1_col4, #T_2b606_row2_col2, #T_2b606_row2_col3, #T_2b606_row2_col4, #T_2b606_row3_col3, #T_2b606_row4_col3, #T_2b606_row5_col3, #T_2b606_row6_col3, #T_2b606_row7_col3, #T_2b606_row8_col2, #T_2b606_row8_col3, #T_2b606_row8_col4, #T_2b606_row9_col2, #T_2b606_row9_col3, #T_2b606_row9_col4, #T_2b606_row10_col2, #T_2b606_row10_col3, #T_2b606_row10_col4, #T_2b606_row11_col2, #T_2b606_row11_col3, #T_2b606_row12_col2, #T_2b606_row12_col3, #T_2b606_row12_col4, #T_2b606_row13_col2, #T_2b606_row13_col3, #T_2b606_row13_col4, #T_2b606_row14_col2, #T_2b606_row14_col3, #T_2b606_row14_col4, #T_2b606_row15_col3, #T_2b606_row16_col2, #T_2b606_row16_col3, #T_2b606_row16_col4, #T_2b606_row17_col2, #T_2b606_row17_col3, #T_2b606_row17_col4, #T_2b606_row18_col2, #T_2b606_row18_col3, #T_2b606_row18_col4, #T_2b606_row19_col2, #T_2b606_row19_col3, #T_2b606_row19_col4 {
#   color: green;
# }
# #T_2b606_row0_col7, #T_2b606_row1_col7, #T_2b606_row2_col7, #T_2b606_row8_col7, #T_2b606_row9_col7, #T_2b606_row10_col7, #T_2b606_row12_col7, #T_2b606_row13_col7, #T_2b606_row14_col7, #T_2b606_row16_col7, #T_2b606_row17_col7, #T_2b606_row18_col7, #T_2b606_row19_col7 {
#   color: white;
#   background-color: green;
# }
# #T_2b606_row3_col2, #T_2b606_row3_col4, #T_2b606_row4_col2, #T_2b606_row4_col4, #T_2b606_row5_col2, #T_2b606_row5_col4, #T_2b606_row6_col2, #T_2b606_row6_col4, #T_2b606_row7_col2, #T_2b606_row7_col4, #T_2b606_row11_col4, #T_2b606_row15_col2, #T_2b606_row15_col4 {
#   color: red;
# }
# #T_2b606_row3_col7, #T_2b606_row4_col7, #T_2b606_row5_col7, #T_2b606_row6_col7, #T_2b606_row7_col7, #T_2b606_row11_col7, #T_2b606_row15_col7 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_2b606_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >treatment</th>
#       <th class="col_heading level0 col1" >metric</th>
#       <th class="col_heading level0 col2" >effect</th>
#       <th class="col_heading level0 col3" >upper</th>
#       <th class="col_heading level0 col4" >lower</th>
#       <th class="col_heading level0 col5" >control_mean</th>
#       <th class="col_heading level0 col6" >treatment_mean</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b606_level0_row0" class="row_heading level0 row0" >15</th>
#       <td id="T_2b606_row0_col0" class="data row0 col0" >T4</td>
#       <td id="T_2b606_row0_col1" class="data row0 col1" >time</td>
#       <td id="T_2b606_row0_col2" class="data row0 col2" >54.007</td>
#       <td id="T_2b606_row0_col3" class="data row0 col3" >74.070</td>
#       <td id="T_2b606_row0_col4" class="data row0 col4" >33.944</td>
#       <td id="T_2b606_row0_col5" class="data row0 col5" >6.245</td>
#       <td id="T_2b606_row0_col6" class="data row0 col6" >9.618</td>
#       <td id="T_2b606_row0_col7" class="data row0 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2b606_level0_row1" class="row_heading level0 row1" >10</th>
#       <td id="T_2b606_row1_col0" class="data row1 col0" >T3</td>
#       <td id="T_2b606_row1_col1" class="data row1 col1" >time</td>
#       <td id="T_2b606_row1_col2" class="data row1 col2" >54.584</td>
#       <td id="T_2b606_row1_col3" class="data row1 col3" >76.291</td>
#       <td id="T_2b606_row1_col4" class="data row1 col4" >32.878</td>
#       <td id="T_2b606_row1_col5" class="data row1 col5" >6.245</td>
#       <td id="T_2b606_row1_col6" class="data row1 col6" >9.654</td>
#       <td id="T_2b606_row1_col7" class="data row1 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2b606_level0_row2" class="row_heading level0 row2" >5</th>
#       <td id="T_2b606_row2_col0" class="data row2 col0" >T2</td>
#       <td id="T_2b606_row2_col1" class="data row2 col1" >time</td>
#       <td id="T_2b606_row2_col2" class="data row2 col2" >35.693</td>
#       <td id="T_2b606_row2_col3" class="data row2 col3" >55.922</td>
#       <td id="T_2b606_row2_col4" class="data row2 col4" >15.464</td>
#       <td id="T_2b606_row2_col5" class="data row2 col5" >6.245</td>
#       <td id="T_2b606_row2_col6" class="data row2 col6" >8.474</td>
#       <td id="T_2b606_row2_col7" class="data row2 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2b606_level0_row3" class="row_heading level0 row3" >0</th>
#       <td id="T_2b606_row3_col0" class="data row3 col0" >T1</td>
#       <td id="T_2b606_row3_col1" class="data row3 col1" >time</td>
#       <td id="T_2b606_row3_col2" class="data row3 col2" >-3.891</td>
#       <td id="T_2b606_row3_col3" class="data row3 col3" >9.295</td>
#       <td id="T_2b606_row3_col4" class="data row3 col4" >-17.076</td>
#       <td id="T_2b606_row3_col5" class="data row3 col5" >6.245</td>
#       <td id="T_2b606_row3_col6" class="data row3 col6" >6.002</td>
#       <td id="T_2b606_row3_col7" class="data row3 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2b606_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_2b606_row4_col0" class="data row4 col0" >T4</td>
#       <td id="T_2b606_row4_col1" class="data row4 col1" >sessions</td>
#       <td id="T_2b606_row4_col2" class="data row4 col2" >-0.481</td>
#       <td id="T_2b606_row4_col3" class="data row4 col3" >4.509</td>
#       <td id="T_2b606_row4_col4" class="data row4 col4" >-5.471</td>
#       <td id="T_2b606_row4_col5" class="data row4 col5" >1.309</td>
#       <td id="T_2b606_row4_col6" class="data row4 col6" >1.303</td>
#       <td id="T_2b606_row4_col7" class="data row4 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2b606_level0_row5" class="row_heading level0 row5" >11</th>
#       <td id="T_2b606_row5_col0" class="data row5 col0" >T3</td>
#       <td id="T_2b606_row5_col1" class="data row5 col1" >sessions</td>
#       <td id="T_2b606_row5_col2" class="data row5 col2" >-2.983</td>
#       <td id="T_2b606_row5_col3" class="data row5 col3" >1.726</td>
#       <td id="T_2b606_row5_col4" class="data row5 col4" >-7.693</td>
#       <td id="T_2b606_row5_col5" class="data row5 col5" >1.309</td>
#       <td id="T_2b606_row5_col6" class="data row5 col6" >1.270</td>
#       <td id="T_2b606_row5_col7" class="data row5 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2b606_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2b606_row6_col0" class="data row6 col0" >T2</td>
#       <td id="T_2b606_row6_col1" class="data row6 col1" >sessions</td>
#       <td id="T_2b606_row6_col2" class="data row6 col2" >-2.740</td>
#       <td id="T_2b606_row6_col3" class="data row6 col3" >2.082</td>
#       <td id="T_2b606_row6_col4" class="data row6 col4" >-7.563</td>
#       <td id="T_2b606_row6_col5" class="data row6 col5" >1.309</td>
#       <td id="T_2b606_row6_col6" class="data row6 col6" >1.273</td>
#       <td id="T_2b606_row6_col7" class="data row6 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2b606_level0_row7" class="row_heading level0 row7" >1</th>
#       <td id="T_2b606_row7_col0" class="data row7 col0" >T1</td>
#       <td id="T_2b606_row7_col1" class="data row7 col1" >sessions</td>
#       <td id="T_2b606_row7_col2" class="data row7 col2" >-2.285</td>
#       <td id="T_2b606_row7_col3" class="data row7 col3" >2.594</td>
#       <td id="T_2b606_row7_col4" class="data row7 col4" >-7.164</td>
#       <td id="T_2b606_row7_col5" class="data row7 col5" >1.309</td>
#       <td id="T_2b606_row7_col6" class="data row7 col6" >1.279</td>
#       <td id="T_2b606_row7_col7" class="data row7 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_2b606_level0_row8" class="row_heading level0 row8" >18</th>
#       <td id="T_2b606_row8_col0" class="data row8 col0" >T4</td>
#       <td id="T_2b606_row8_col1" class="data row8 col1" >mean_tracks_per_session</td>
#       <td id="T_2b606_row8_col2" class="data row8 col2" >28.622</td>
#       <td id="T_2b606_row8_col3" class="data row8 col3" >39.221</td>
#       <td id="T_2b606_row8_col4" class="data row8 col4" >18.023</td>
#       <td id="T_2b606_row8_col5" class="data row8 col5" >9.755</td>

# %%
def color(value):
    return 'color:red;' if value < 0 else 'color:green;'

def background(value):
    return 'color:white;background-color:green' if value else 'color:white;background-color:red'
        

(
    pd.DataFrame(effects)[[
        "treatment", 
        "metric",
        "effect", 
        "upper", 
        "lower", 
        "control_mean", 
        "treatment_mean",
        "significant"
    ]]
    .sort_values(["metric", "treatment"], ascending=False)
    .style
    .applymap(color, subset=["effect", "upper", "lower"])
    .applymap(background, subset=["significant"])
)
# Out:
# <style type="text/css">
# #T_58c3b_row0_col2, #T_58c3b_row0_col3, #T_58c3b_row0_col4, #T_58c3b_row1_col2, #T_58c3b_row1_col3, #T_58c3b_row1_col4, #T_58c3b_row2_col2, #T_58c3b_row2_col3, #T_58c3b_row2_col4, #T_58c3b_row3_col2, #T_58c3b_row3_col3, #T_58c3b_row3_col4, #T_58c3b_row4_col2, #T_58c3b_row4_col3, #T_58c3b_row4_col4, #T_58c3b_row5_col3, #T_58c3b_row6_col2, #T_58c3b_row6_col3, #T_58c3b_row7_col3, #T_58c3b_row8_col3, #T_58c3b_row9_col3, #T_58c3b_row10_col2, #T_58c3b_row10_col3, #T_58c3b_row10_col4, #T_58c3b_row11_col2, #T_58c3b_row11_col3, #T_58c3b_row11_col4, #T_58c3b_row12_col2, #T_58c3b_row12_col3, #T_58c3b_row12_col4, #T_58c3b_row13_col2, #T_58c3b_row13_col3, #T_58c3b_row13_col4, #T_58c3b_row14_col2, #T_58c3b_row14_col3, #T_58c3b_row14_col4, #T_58c3b_row15_col2, #T_58c3b_row15_col3, #T_58c3b_row15_col4, #T_58c3b_row16_col2, #T_58c3b_row16_col3, #T_58c3b_row16_col4, #T_58c3b_row17_col2, #T_58c3b_row17_col3, #T_58c3b_row17_col4, #T_58c3b_row18_col2, #T_58c3b_row18_col3, #T_58c3b_row18_col4, #T_58c3b_row19_col2, #T_58c3b_row19_col3, #T_58c3b_row19_col4, #T_58c3b_row20_col2, #T_58c3b_row20_col3, #T_58c3b_row20_col4, #T_58c3b_row21_col2, #T_58c3b_row21_col3, #T_58c3b_row21_col4, #T_58c3b_row22_col2, #T_58c3b_row22_col3, #T_58c3b_row22_col4, #T_58c3b_row23_col2, #T_58c3b_row23_col3, #T_58c3b_row23_col4, #T_58c3b_row24_col2, #T_58c3b_row24_col3, #T_58c3b_row24_col4 {
#   color: green;
# }
# #T_58c3b_row0_col7, #T_58c3b_row1_col7, #T_58c3b_row2_col7, #T_58c3b_row3_col7, #T_58c3b_row4_col7, #T_58c3b_row10_col7, #T_58c3b_row11_col7, #T_58c3b_row12_col7, #T_58c3b_row13_col7, #T_58c3b_row14_col7, #T_58c3b_row15_col7, #T_58c3b_row16_col7, #T_58c3b_row17_col7, #T_58c3b_row18_col7, #T_58c3b_row19_col7, #T_58c3b_row20_col7, #T_58c3b_row21_col7, #T_58c3b_row22_col7, #T_58c3b_row23_col7, #T_58c3b_row24_col7 {
#   color: white;
#   background-color: green;
# }
# #T_58c3b_row5_col2, #T_58c3b_row5_col4, #T_58c3b_row6_col4, #T_58c3b_row7_col2, #T_58c3b_row7_col4, #T_58c3b_row8_col2, #T_58c3b_row8_col4, #T_58c3b_row9_col2, #T_58c3b_row9_col4 {
#   color: red;
# }
# #T_58c3b_row5_col7, #T_58c3b_row6_col7, #T_58c3b_row7_col7, #T_58c3b_row8_col7, #T_58c3b_row9_col7 {
#   color: white;
#   background-color: red;
# }
# </style>
# <table id="T_58c3b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >treatment</th>
#       <th class="col_heading level0 col1" >metric</th>
#       <th class="col_heading level0 col2" >effect</th>
#       <th class="col_heading level0 col3" >upper</th>
#       <th class="col_heading level0 col4" >lower</th>
#       <th class="col_heading level0 col5" >control_mean</th>
#       <th class="col_heading level0 col6" >treatment_mean</th>
#       <th class="col_heading level0 col7" >significant</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_58c3b_level0_row0" class="row_heading level0 row0" >20</th>
#       <td id="T_58c3b_row0_col0" class="data row0 col0" >T5</td>
#       <td id="T_58c3b_row0_col1" class="data row0 col1" >time</td>
#       <td id="T_58c3b_row0_col2" class="data row0 col2" >260.721</td>
#       <td id="T_58c3b_row0_col3" class="data row0 col3" >302.187</td>
#       <td id="T_58c3b_row0_col4" class="data row0 col4" >219.256</td>
#       <td id="T_58c3b_row0_col5" class="data row0 col5" >2.924</td>
#       <td id="T_58c3b_row0_col6" class="data row0 col6" >10.547</td>
#       <td id="T_58c3b_row0_col7" class="data row0 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_58c3b_level0_row1" class="row_heading level0 row1" >15</th>
#       <td id="T_58c3b_row1_col0" class="data row1 col0" >T4</td>
#       <td id="T_58c3b_row1_col1" class="data row1 col1" >time</td>
#       <td id="T_58c3b_row1_col2" class="data row1 col2" >303.123</td>
#       <td id="T_58c3b_row1_col3" class="data row1 col3" >350.499</td>
#       <td id="T_58c3b_row1_col4" class="data row1 col4" >255.746</td>
#       <td id="T_58c3b_row1_col5" class="data row1 col5" >2.924</td>
#       <td id="T_58c3b_row1_col6" class="data row1 col6" >11.787</td>
#       <td id="T_58c3b_row1_col7" class="data row1 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_58c3b_level0_row2" class="row_heading level0 row2" >10</th>
#       <td id="T_58c3b_row2_col0" class="data row2 col0" >T3</td>
#       <td id="T_58c3b_row2_col1" class="data row2 col1" >time</td>
#       <td id="T_58c3b_row2_col2" class="data row2 col2" >192.980</td>
#       <td id="T_58c3b_row2_col3" class="data row2 col3" >229.615</td>
#       <td id="T_58c3b_row2_col4" class="data row2 col4" >156.346</td>
#       <td id="T_58c3b_row2_col5" class="data row2 col5" >2.924</td>
#       <td id="T_58c3b_row2_col6" class="data row2 col6" >8.566</td>
#       <td id="T_58c3b_row2_col7" class="data row2 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_58c3b_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_58c3b_row3_col0" class="data row3 col0" >T2</td>
#       <td id="T_58c3b_row3_col1" class="data row3 col1" >time</td>
#       <td id="T_58c3b_row3_col2" class="data row3 col2" >150.007</td>
#       <td id="T_58c3b_row3_col3" class="data row3 col3" >178.011</td>
#       <td id="T_58c3b_row3_col4" class="data row3 col4" >122.003</td>
#       <td id="T_58c3b_row3_col5" class="data row3 col5" >2.924</td>
#       <td id="T_58c3b_row3_col6" class="data row3 col6" >7.310</td>
#       <td id="T_58c3b_row3_col7" class="data row3 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_58c3b_level0_row4" class="row_heading level0 row4" >0</th>
#       <td id="T_58c3b_row4_col0" class="data row4 col0" >T1</td>
#       <td id="T_58c3b_row4_col1" class="data row4 col1" >time</td>
#       <td id="T_58c3b_row4_col2" class="data row4 col2" >133.761</td>
#       <td id="T_58c3b_row4_col3" class="data row4 col3" >153.773</td>
#       <td id="T_58c3b_row4_col4" class="data row4 col4" >113.749</td>
#       <td id="T_58c3b_row4_col5" class="data row4 col5" >2.924</td>
#       <td id="T_58c3b_row4_col6" class="data row4 col6" >6.835</td>
#       <td id="T_58c3b_row4_col7" class="data row4 col7" >True</td>
#     </tr>
#     <tr>
#       <th id="T_58c3b_level0_row5" class="row_heading level0 row5" >21</th>
#       <td id="T_58c3b_row5_col0" class="data row5 col0" >T5</td>
#       <td id="T_58c3b_row5_col1" class="data row5 col1" >sessions</td>
#       <td id="T_58c3b_row5_col2" class="data row5 col2" >-0.164</td>
#       <td id="T_58c3b_row5_col3" class="data row5 col3" >4.738</td>
#       <td id="T_58c3b_row5_col4" class="data row5 col4" >-5.066</td>
#       <td id="T_58c3b_row5_col5" class="data row5 col5" >1.411</td>
#       <td id="T_58c3b_row5_col6" class="data row5 col6" >1.409</td>
#       <td id="T_58c3b_row5_col7" class="data row5 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_58c3b_level0_row6" class="row_heading level0 row6" >16</th>
#       <td id="T_58c3b_row6_col0" class="data row6 col0" >T4</td>
#       <td id="T_58c3b_row6_col1" class="data row6 col1" >sessions</td>
#       <td id="T_58c3b_row6_col2" class="data row6 col2" >1.210</td>
#       <td id="T_58c3b_row6_col3" class="data row6 col3" >6.356</td>
#       <td id="T_58c3b_row6_col4" class="data row6 col4" >-3.936</td>
#       <td id="T_58c3b_row6_col5" class="data row6 col5" >1.411</td>
#       <td id="T_58c3b_row6_col6" class="data row6 col6" >1.428</td>
#       <td id="T_58c3b_row6_col7" class="data row6 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_58c3b_level0_row7" class="row_heading level0 row7" >11</th>
#       <td id="T_58c3b_row7_col0" class="data row7 col0" >T3</td>
#       <td id="T_58c3b_row7_col1" class="data row7 col1" >sessions</td>
#       <td id="T_58c3b_row7_col2" class="data row7 col2" >-0.927</td>
#       <td id="T_58c3b_row7_col3" class="data row7 col3" >4.029</td>
#       <td id="T_58c3b_row7_col4" class="data row7 col4" >-5.882</td>
#       <td id="T_58c3b_row7_col5" class="data row7 col5" >1.411</td>
#       <td id="T_58c3b_row7_col6" class="data row7 col6" >1.398</td>
#       <td id="T_58c3b_row7_col7" class="data row7 col7" >False</td>
#     </tr>
#     <tr>
#       <th id="T_58c3b_level0_row8" class="row_heading level0 row8" >6</th>

# %%
from dataclasses import dataclass
@dataclass
class Info:
    id: int

d = {}
d[1] = Info(123)

i = d[1]
i.id = 321

d
# Out:
# {1: Info(id=321)}
